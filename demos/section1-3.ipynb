# %% [markdown]
# # Section 1.3
# ## Example 1.3.2

# %%
using FNCFunctions

# %%
FNC.horner
# Out:
# horner (generic function with 1 method)

# %%
c = [-1, 3, -3, 1]
FNC.horner(c, 1.6)
# Out:
# 0.21600000000000041

# %%
using Polynomials
p = Polynomial(c)
# Out:
# Polynomial(-1 + 3*x - 3*x^2 + x^3)

# %%
p(1.6)
# Out:
# 0.21600000000000008
